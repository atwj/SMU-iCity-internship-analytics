# %%
#imports
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

#plot
# Create the figure and configure
fig = plt.figure(figsize=(8,8))
# Add subplot of polar projection
ax1 = fig.add_subplot(111, projection='polar')
# Add 24 xtick points of (0,23) representing the hours in a day
ax1.set_xticks(np.linspace(0,23,24,endpoint=True, dtype=np.int32) / 24 * (2 * np.pi))
# Generate xtick labels from [0,23]
xticklabels = [str(x) for x in range (0,24)]
# Set xtick labels
ax1.set_xticklabels(xticklabels)
# Set 0 degrees to 'North'
ax1.set_theta_zero_location('N')
# Set values to increment clockwise
ax1.set_theta_direction(-1)
ax1.set_yticks([0.6,0.8])
ax1.set_yticklabels(['Wake-time', 'Sleep-time'])
ax1.plot([0.2,0.3,0.4])
plt.show()
# Out:
# ------------------------------------------------------------
# ValueError                 Traceback (most recent call last)
# <ipython-input-6-f2d62a4e6757> in <module>()
#      21 ax1.set_yticks([0.6,0.8])
#      22 ax1.set_yticklabels(['Wake-time', 'Sleep-time'])
# ---> 23 ax1.plot([0.2,0.3,0.4],'Wake-time')
#      24 plt.show()
#
# /Users/AMOS/.pyenv/versions/anaconda3-4.0.0/envs/test/lib/python3.5/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1810                     warnings.warn(msg % (label_namer, func.__name__),
#    1811                                   RuntimeWarning, stacklevel=2)
# -> 1812             return func(ax, *args, **kwargs)
#    1813         pre_doc = inner.__doc__
#    1814         if pre_doc is None:
#
# /Users/AMOS/.pyenv/versions/anaconda3-4.0.0/envs/test/lib/python3.5/site-packages/matplotlib/axes/_axes.py in plot(self, *args, **kwargs)
#    1422             kwargs['color'] = c
#    1423
# -> 1424         for line in self._get_lines(*args, **kwargs):
#    1425             self.add_line(line)
#    1426             lines.append(line)
#
# /Users/AMOS/.pyenv/versions/anaconda3-4.0.0/envs/test/lib/python3.5/site-packages/matplotlib/axes/_base.py in _grab_next_args(self, *args, **kwargs)
#     384                 return
#     385             if len(remaining) <= 3:
# --> 386                 for seg in self._plot_args(remaining, kwargs):
#     387                     yield seg
#     388                 return
#
# /Users/AMOS/.pyenv/versions/anaconda3-4.0.0/envs/test/lib/python3.5/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     334         ret = []
#     335         if len(tup) > 1 and is_string_like(tup[-1]):
# --> 336             linestyle, marker, color = _process_plot_format(tup[-1])
#     337             tup = tup[:-1]
#     338         elif len(tup) == 3:
#
# /Users/AMOS/.pyenv/versions/anaconda3-4.0.0/envs/test/lib/python3.5/site-packages/matplotlib/axes/_base.py in _process_plot_format(fmt)
#     114         else:
#     115             raise ValueError(
# --> 116                 'Unrecognized character %c in format string' % c)
#     117
#     118     if linestyle is None and marker is None:
#
# ValueError: Unrecognized character W in format string
